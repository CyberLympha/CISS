# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import datetime
import re, struct


from typing import Dict

import warnings

# %%
seed_value = 36

import os
os.environ['PYTHONHASHSEED'] = str(seed_value)

import random
random.seed(seed_value)

import numpy as np
np.random.seed(seed_value)

import tensorflow as tf
tf.random.set_seed(seed_value)
# Out:
# 2022-09-09 07:51:10.813039: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory
# 2022-09-09 07:51:10.813058: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# /home/askorohodov/.local/lib/python3.7/site-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.12) or chardet (5.0.0) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
from src.preprocessing import prepare_data, get_traintest
from src.processing import Predictor
from src.visualization import plot_result
from src.models.simple_models import OCSVM, LOF, iForest
from src.models.ae_lstm import AE_LSTM
from src.models.som import SOM

# %%
model_store_path = './saved_models/'

# %%
#pd.set_option('display.max_rows', 150)

# %% [markdown]
# # Загрузка данных

# %%
data = pd.read_csv('/opt/notebooks/cerebrum/CISS2022/ARPE/splitted_payload_192_168_1_10.csv', 
                   index_col='timestamp', 
                   parse_dates=True,
                   infer_datetime_format = True)
data
# Out:
#                                                            path        id  \
# timestamp
# 1.575598e+09  /opt/datasets/cerebrum/SWAT/SWaT.A6_Dec 2019/D...      1107
# 1.575598e+09  /opt/datasets/cerebrum/SWAT/SWaT.A6_Dec 2019/D...      1108
# 1.575598e+09  /opt/datasets/cerebrum/SWAT/SWaT.A6_Dec 2019/D...      3873
# 1.575598e+09  /opt/datasets/cerebrum/SWAT/SWaT.A6_Dec 2019/D...      3874
# 1.575598e+09  /opt/datasets/cerebrum/SWAT/SWaT.A6_Dec 2019/D...     14933
# ...                                                         ...       ...
# 1.575611e+09  /opt/datasets/cerebrum/SWAT/SWaT.A6_Dec 2019/D...  21902947
# 1.575611e+09  /opt/datasets/cerebrum/SWAT/SWaT.A6_Dec 2019/D...  21915746
# 1.575611e+09  /opt/datasets/cerebrum/SWAT/SWaT.A6_Dec 2019/D...  21915747
# 1.575611e+09  /opt/datasets/cerebrum/SWAT/SWaT.A6_Dec 2019/D...  21927579
# 1.575611e+09  /opt/datasets/cerebrum/SWAT/SWaT.A6_Dec 2019/D...  21927580
#
#                     connection_id  \
# timestamp
# 1.575598e+09  b'\x80\x00\xfe\xb3'
# 1.575598e+09  b'\x80\x00\xfe\xb3'
# 1.575598e+09  b'\x80\x00\xfe\xb3'
# 1.575598e+09  b'\x80\x00\xfe\xb3'
# 1.575598e+09  b'\x80\x00\xfe\xb3'
# ...                           ...
# 1.575611e+09  b'\x80\x00\xfe\xb3'
# 1.575611e+09  b'\x80\x00\xfe\xb3'
# 1.575611e+09  b'\x80\x00\xfe\xb3'
# 1.575611e+09  b'\x80\x00\xfe\xb3'
# 1.575611e+09  b'\x80\x00\xfe\xb3'
#
#                                                        raw_data  len  \
# timestamp
# 1.575598e+09  b"\x00\x00\x00\x00\xff\xff\xff\xff\x00\x03B\xe...  135
# 1.575598e+09  b"\x00\x00\x00\x00\xff\xff\xff\xff\x00\x03B\xe...  135
# 1.575598e+09  b"\x00\x00\x00\x00\xff\xff\xff\xff\x00\x03B\xe...  135
# 1.575598e+09  b"\x00\x00\x00\x00\xff\xff\xff\xff\x00\x03B\xe...  135
# 1.575598e+09  b"\x00\x00\x00\x00\xff\xff\xff\xff\x00\x03B\xe...  135
# ...                                                         ...  ...
# 1.575611e+09  b"\x00\x00\x00\x00\xff\xff\xff\xff\x00\x03B\xe...  135
# 1.575611e+09  b"\x00\x00\x00\x00\xff\xff\xff\xff\x00\x03B\xe...  135
# 1.575611e+09  b"\x00\x00\x00\x00\xff\xff\xff\xff\x00\x03B\xe...  135
# 1.575611e+09  b"\x00\x00\x00\x00\xff\xff\xff\xff\x00\x03B\xe...  135
# 1.575611e+09  b"\x00\x00\x00\x00\xff\xff\xff\xff\x00\x03B\xe...  135
#
#                                                        int_data        0  \
# timestamp
# 1.575598e+09  (0, 0, 0, 0, 255, 255, 255, 255, 0, 3, 66, 231...  b'\x00'
# 1.575598e+09  (0, 0, 0, 0, 255, 255, 255, 255, 0, 3, 66, 231...  b'\x00'
# 1.575598e+09  (0, 0, 0, 0, 255, 255, 255, 255, 0, 3, 66, 231...  b'\x00'
# 1.575598e+09  (0, 0, 0, 0, 255, 255, 255, 255, 0, 3, 66, 231...  b'\x00'
# 1.575598e+09  (0, 0, 0, 0, 255, 255, 255, 255, 0, 3, 66, 231...  b'\x00'
# ...                                                         ...      ...
# 1.575611e+09  (0, 0, 0, 0, 255, 255, 255, 255, 0, 3, 66, 235...  b'\x00'
# 1.575611e+09  (0, 0, 0, 0, 255, 255, 255, 255, 0, 3, 66, 235...  b'\x00'
# 1.575611e+09  (0, 0, 0, 0, 255, 255, 255, 255, 0, 3, 66, 235...  b'\x00'
# 1.575611e+09  (0, 0, 0, 0, 255, 255, 255, 255, 0, 3, 66, 235...  b'\x00'
# 1.575611e+09  (0, 0, 0, 0, 255, 255, 255, 255, 0, 3, 66, 235...  b'\x00'
#
#                     1        2        3  ...       71        72     73  \
# timestamp                                ...
# 1.575598e+09  b'\x00'  b'\xff'  b'\xff'  ...  b'\xc0'  b'\x00>'  b"'z"
# 1.575598e+09  b'\x00'  b'\xff'  b'\xff'  ...  b'\xc0'  b'\x00>'  b"'z"
# 1.575598e+09  b'\x00'  b'\xff'  b'\xff'  ...  b'\xc0'  b'\x00>'  b"'z"
# 1.575598e+09  b'\x00'  b'\xff'  b'\xff'  ...  b'\xc0'  b'\x00>'  b"'z"
# 1.575598e+09  b'\x00'  b'\xff'  b'\xff'  ...  b'\xc0'  b'\x00>'  b"'z"
# ...               ...      ...      ...  ...      ...       ...    ...
# 1.575611e+09  b'\x00'  b'\xff'  b'\xff'  ...  b'\xc0'  b'\x00>'  b"'z"
# 1.575611e+09  b'\x00'  b'\xff'  b'\xff'  ...  b'\xc0'  b'\x00>'  b"'z"
# 1.575611e+09  b'\x00'  b'\xff'  b'\xff'  ...  b'\xc0'  b'\x00>'  b"'z"
# 1.575611e+09  b'\x00'  b'\xff'  b'\xff'  ...  b'\xc0'  b'\x00>'  b"'z"
# 1.575611e+09  b'\x00'  b'\xff'  b'\xff'  ...  b'\xc0'  b'\x00>'  b"'z"
#
#                     74           75           76           77           78  \
# timestamp
# 1.575598e+09  b'\xab>'  b'\x05\xfa'  b'\xab\x00'  b'\x01\x00'  b'\x00\x00'
# 2019-12-06 02:05:04.913991928  b'\x00\x00'  b'\xcc'  b'\xcc\xad\xc2'
# ...                                    ...      ...              ...
# 2019-12-06 05:45:02.793700933  b'\x00\x00'  b'\xcc'        b'\xcc_g'
# 2019-12-06 05:45:03.292222023  b'\x00\x00'  b'\xcc'        b'\xcc_h'
# 2019-12-06 05:45:03.292222977  b'\x00\x00'  b'\xcc'        b'\xcc_h'
# 2019-12-06 05:45:03.796188116  b'\x00\x00'  b'\xcc'        b'\xcc_i'
# 2019-12-06 05:45:03.796189070  b'\x00\x00'  b'\xcc'        b'\xcc_i'
#
# [86800 rows x 87 columns]

# %% [markdown]
# ### Работаем с byte

# %%
df_bytes = data.copy().drop(['path', 'connection_id', 'raw_data', 'len', 'int_data'], axis=1)

# %%
df_bytes
# Out:
#                                      id        0        1        2        3  \
# timestamp
# 2019-12-06 02:05:04.415631056      1107  b'\x00'  b'\x00'  b'\xff'  b'\xff'
# 2019-12-06 02:05:04.415632010      1108  b'\x00'  b'\x00'  b'\xff'  b'\xff'
# 2019-12-06 02:05:04.532814026      3873  b'\x00'  b'\x00'  b'\xff'  b'\xff'
# 2019-12-06 02:05:04.532814980      3874  b'\x00'  b'\x00'  b'\xff'  b'\xff'
# 2019-12-06 02:05:04.913991928     14933  b'\x00'  b'\x00'  b'\xff'  b'\xff'
# ...                                 ...      ...      ...      ...      ...
# 2019-12-06 05:45:02.793700933  21902947  b'\x00'  b'\x00'  b'\xff'  b'\xff'
# 2019-12-06 05:45:03.292222023  21915746  b'\x00'  b'\x00'  b'\xff'  b'\xff'
# 2019-12-06 05:45:03.292222977  21915747  b'\x00'  b'\x00'  b'\xff'  b'\xff'
# 2019-12-06 05:45:03.796188116  21927579  b'\x00'  b'\x00'  b'\xff'  b'\xff'
# 2019-12-06 05:45:03.796189070  21927580  b'\x00'  b'\x00'  b'\xff'  b'\xff'
#
#                                      4        5            6         7  \
# timestamp
# 2019-12-06 02:05:04.415631056  b'\xff'  b'\xff'  b'\x00\x03'  b'B\xe7'
# 2019-12-06 02:05:04.415632010  b'\xff'  b'\xff'  b'\x00\x03'  b'B\xe7'
# 2019-12-06 02:05:04.532814026  b'\xff'  b'\xff'  b'\x00\x03'  b'B\xe7'
# 2019-12-06 02:05:04.532814980  b'\xff'  b'\xff'  b'\x00\x03'  b'B\xe7'
# 2019-12-06 02:05:04.913991928  b'\xff'  b'\xff'  b'\x00\x03'  b'B\xe7'
# ...                                ...      ...          ...       ...
# 2019-12-06 05:45:02.793700933  b'\xff'  b'\xff'  b'\x00\x03'  b'B\xeb'
# 2019-12-06 05:45:03.292222023  b'\xff'  b'\xff'  b'\x00\x03'  b'B\xeb'
# 2019-12-06 05:45:03.292222977  b'\xff'  b'\xff'  b'\x00\x03'  b'B\xeb'
# 2019-12-06 05:45:03.796188116  b'\xff'  b'\xff'  b'\x00\x03'  b'B\xeb'
# 2019-12-06 05:45:03.796189070  b'\xff'  b'\xff'  b'\x00\x03'  b'B\xeb'
#
#                                          8  ...       71        72     73  \
# timestamp                                   ...
# 2019-12-06 02:05:04.415631056  b'\xcc\xad\xc0'
# 2019-12-06 02:05:04.415632010  b'\xcc\xad\xc0'
# 2019-12-06 02:05:04.532814026  b'\xcc\xad\xc1'
# 2019-12-06 02:05:04.532814980  b'\xcc\xad\xc1'
# 2019-12-06 02:05:04.913991928  b'\xcc\xad\xc2'
# ...                                        ...
# 2019-12-06 05:45:02.793700933        b'\xcc_g'
# 2019-12-06 05:45:03.292222023        b'\xcc_h'
# 2019-12-06 05:45:03.292222977        b'\xcc_h'
# 2019-12-06 05:45:03.796188116        b'\xcc_i'
# 2019-12-06 05:45:03.796189070        b'\xcc_i'
#
# [86800 rows x 82 columns]

# %%
df_bytes = df_bytes[~df_bytes.index.duplicated(keep='first')].sort_index()

# %%
def extract_bytes(value):
    splitted_string = re.split(r'\\x', value[:-1])
    if len(splitted_string) > 1:
        splitted_bytes = splitted_string[1:]
        return splitted_bytes
    else:
        return None
    
def count_bytes_len(value):
    splitted_string = re.split(r'\\x', value[:-1])
    
    return len(splitted_string)

def convert_bytes(string_hex):
    
    try:
        bytes_list = re.findall(r'\\x\w{2}', string_hex)
        if len(bytes_list) == 1:
            return struct.unpack('B', bytes_list[0].encode().decode('unicode_escape').encode("raw_unicode_escape"))[0]
        
        elif len(bytes_list) == 2:
            return struct.unpack('H', ''.join(bytes_list).encode().decode('unicode_escape').encode("raw_unicode_escape"))[0]
        
        elif len(bytes_list) == 3:
            if bytes_list == ['\\x00', '\\x00', '\\x00']: 
                return -1
            else:
                #rint('[3]', bytes_list)
                return -1
        
        elif len(bytes_list) == 4:
            return struct.unpack('<f',''.join(bytes_list).encode().decode('unicode_escape').encode("raw_unicode_escape"))[0]
            
        
    except Exception as err:
        print(err, string_hex)
        return None

# %%
df_bytes_ = df_bytes.drop('id', axis=1)
df_bytes_len = df_bytes_.applymap(count_bytes_len)
not_byte_columns = []
constant_columns = []

for col in df_bytes_len.columns:
    col_unique_values = df_bytes_len[col].unique()
    if col_unique_values.shape[0]==1 and col_unique_values[0]==1:
        not_byte_columns.append(col)
        
print('not bytes:', not_byte_columns, 'lenght:', len(not_byte_columns))

for col in df_bytes_len.drop(not_byte_columns, axis=1).columns:
    col_unique_values = df_bytes_[col].unique()
    if col_unique_values.shape[0]==1:
        constant_columns.append(col)

print('constant:', constant_columns, 'lenght:', len(constant_columns))

df_bytes_ = df_bytes_.drop(constant_columns+not_byte_columns, axis=1)
# Out:
# not bytes: ['11', '13', '15', '16', '24', '25', '26', '27', '31', '42', '49', '54', '55', '63', '64', '69', '73'] lenght: 17
# constant: ['0', '1', '2', '3', '4', '6', '9', '10', '12', '14', '17', '18', '20', '23', '28', '29', '34', '36', '43', '44', '45', '46', '47', '48', '50', '57', '58', '59', '60', '61', '62', '65', '70', '71', '72', '74', '75', '76', '77', '78', '79'] lenght: 41

# %%
df_bytes_
# Out:
#                                      5         7            8           19  \
# timestamp
# 2019-12-06 02:05:04.415631056  b'\xff'  b'B\xe7'     b';\xbc'  b'\x01\x00'
# 2019-12-06 02:05:04.415632010  b'\xff'  b'B\xe7'     b';\xbc'  b'\x01\x00'
# Out:
# b'\xff'    53917
# b'\xfd'    30485
# Name: 5, dtype: int64
# b'B\xe9'    22551
# b'B\xe8'    19753
# b'B\xeb'    17074
# b'B\xea'    15681
# b'B\xe7'     9343
# Name: 7, dtype: int64
# b'\x99\x9a'    9660
# b'\xf7w'       8478
# b'L\xcd'       8381
# b'\x91\x11'    5616
# b'\xee\xef'    5190
# b'\xdd\xde'    3618
# b'\xaa\xab'    2047
# b'\xb33'       2041
# b'\x80\x00'    2031
# b'ff'          2028
# b'\x88\x89'    2023
# b'ww'          2019
# b'DD'          2015
# b'\xbb\xbc'    2006
# b'UU'          2001
# b'\xa2"'       1993
# b'n\xef'       1971
# b']\xde'       1954
# b'\xc4D'       1628
# b'\x08\x89'    1627
# b'\xe6f'       1627
# b'\x19\x9a'    1626
# b'*\xab'       1621
# b'\xd5U'       1616
# b'\x00\x00'    1614
# b'""'          1608
# b'\xcc\xcd'    1605
# b'33'          1595
# b'\x11\x11'    1593
# b';\xbc'       1570
# Name: 8, dtype: int64
# b'\x01\x00'    78392
# b'\x00\x00'     6010
# Name: 19, dtype: int64
# b'\x01\x01'    53871
# b'\x01\x00'    30531
# Name: 21, dtype: int64
# b'\x00\x03'    45807
# b'\x00\x02'    38595
# Name: 22, dtype: int64
# b'\x00\x02'    53871
# b'\x00\x01'    30531
# Name: 30, dtype: int64
# b't\x88'       8063
# b'\x7fw'       7257
# b'\x85\x11'    6788
# b'|D'          4023
# b'\x83\x99'    4017
#                ...
# b'q\x99'        375
# b'\x813'        375
# b'\x87U'        351
# b'\x85U'        350
# b'i\x99'         13
# Name: 32, Length: 137, dtype: int64
# b'\x89\x01'    11332
# b'w\x01'       10504
# b'\x11\x01'    10030
# b'D\x01'        7196
# b'\x9a\x01'     6761
# b'\xab\x01'     5671
# b'\xef\x01'     4057
# b'3\x01'        3960
# b'\x00\x01'     3650
# b'\xbc\x01'     3646
# b'f\x01'        3622
# b'\xcd\x01'     3612
# b'"\x01'        3591
# b'U\x01'        3537
# b'\xde\x01'     3233
# Name: 33, dtype: int64
# b'\x02'    53871
# b'\x01'    30531
# Name: 35, dtype: int64
# b'\x02\x00'    53916
# b'\x01\x00'    29918
# b'\x00\x00'      568
# Name: 37, dtype: int64
# b'\x02\x13'    54185
# b'\x01\x13'    30217
# Name: 38, dtype: int64
# b'\x00\x01'    80386
# b'\x00\x02'     3788
# b'\x00\x00'      228
# Name: 39, dtype: int64
# b'\x00\x01'    80500
# b'\x00\x02'     3902
# Name: 40, dtype: int64
# b'\x13C'    78394
# b'\x01C'     6008
# Name: 41, dtype: int64
# b'\x00D'    83211
# b'\x00C'     1191
# Name: 51, dtype: int64
# b'K\xbd'       358
# b'K\xb3'       353
# b'K\xb1'       333
# b'K\xb8'       325
# b'K\xbb'       307
#               ...
# b'#\x89'         1
# b'\x1aZ'         1
# b'!B'            1
# b'\x14\xa1'      1
# b'\x1d\xf3'      1
# Name: 52, Length: 5804, dtype: int64
# b'W '       512
# b'\xce '    492
# b'\x19 '    482
# b'\xa8 '    473
# b'8 '       459
#            ...
# b'\x87$'      2
# b'z$'         2
# b'\x16$'      2
# b'\xd8$'      2
# b'o$'         2
# Name: 53, Length: 542, dtype: int64
# b'\xbb\xc1'    29357
# b'\x1c\xeb'    24871
# b'gD'          20317
# b'<\xfd'        6081
# b'\x0e;'          10
#                ...
# b'\xfd\xfc'        4
# b'\xfd^'           4
# b'\xff;'           4
# b'\xff\xdb'        4
# b'&L'              3
# Name: 56, Length: 557, dtype: int64
# b'\x00\x00'    74267
# b'@ '           6008
# b'@\x8b'        2049
# b'@\x8c'        1694
# b'@\x89'          18
#                ...
# b'>A'              2
# b'@+'              1
# b'>-'              1
# b'@n'              1
# b'>\x8c'           1
# Name: 66, Length: 140, dtype: int64
# b'\x00\x00\x00'    80275
# b'S\xcb\x04'         112
# b'\xc3}\x04'         110
# b'\xf7\xf7\x04'      104
# b'\x96\xe3\x04'      103
#                    ...
# b'.Q\x04'              2
# b'\xdc:\x04'           1
# b'\x96\x19\x04'        1
# b'\x15\xe6\x04'        1
# b's*\x04'              1
# Name: 67, Length: 275, dtype: int64
# b'\x0c'    74365
# b'\x10'     6008
# b'\x03'     3841
# b'\x00'       94
# b'\x02'       65
# b'\x04'       29
# Name: 68, dtype: int64
# b'\xcc\xd4\xb6'    4
# b'\xccXt'          4
# b'\xcc\xd5\xda'    3
# b'\xcc\xd5\xb5'    2
# b'\xcc!\xc4'       2
#                   ..
# b'\xcc2\x15'       1
# b'\xcc$w'          1
# b'\xcc\x0b\xfc'    1
# b'\xccJ\xdc'       1
# b'\xcc:~'          1
# Name: 80, Length: 43397, dtype: int64

# %%
df_bytes_.iloc[10,10]
# Out:
# "b'\\x02\\x00'"

# %%
bytes(df_bytes_.iloc[10,10],encoding='utf-8')
# Out:
# b"b'\\x02\\x00'"

# %%
x = re.findall(r'\\x\w{2}', df_bytes_.iloc[0,3])
x
# Out:
# ['\\x01', '\\x00']

# %%
''.join(x).encode().decode('unicode_escape').encode("raw_unicode_escape")
# Out:
# b'\x01\x00'

# %%
struct.unpack('H', ''.join(x).encode().decode('unicode_escape').encode("raw_unicode_escape"))
# Out:
# (1,)

# %%
df_bytes_converted = df_bytes_.applymap(convert_bytes)
df_bytes_converted['id'] = df_bytes['id']
df_bytes_converted
# Out:
#                                  5    7        8  19   21   22   30     32  \
# timestamp
# 2019-12-06 02:05:04.415631056  255  231    188.0   1  257  768  512  153.0
# 2019-12-06 02:05:04.415632010  255  231    188.0   1  257  768  512  153.0
# 2019-12-06 02:05:04.532814026  255  231    188.0   1  257  768  512  153.0
# 2019-12-06 02:05:04.532814980  255  231    188.0   1  257  768  512  153.0
# 2019-12-06 02:05:04.913991928  255  231    188.0   1  257  768  512  153.0
# ...                            ...  ...      ...  ..  ...  ...  ...    ...
# 2019-12-06 05:45:02.793700933  255  235  57053.0   1  257  512  512  135.0
# 2019-12-06 05:45:03.292222023  255  235  57053.0   1  257  512  512  135.0
# 2019-12-06 05:45:03.292222977  255  235  57053.0   1  257  512  512  135.0
# 2019-12-06 05:45:03.796188116  255  235  57053.0   1  257  512  512  135.0
# 2019-12-06 05:45:03.796189070  255  235  57053.0   1  257  512  512  135.0
# 2019-12-06 02:05:04.913991928  410   2  ...  19   0  248.0    NaN  253.0  0.0
# ...                            ...  ..  ...  ..  ..    ...    ...    ...  ...
# 2019-12-06 05:45:02.793700933    1   2  ...  19   0    NaN  246.0    NaN  0.0
# 2019-12-06 05:45:03.292222023    1   2  ...  19   0    NaN  240.0    NaN  0.0
# 2019-12-06 05:45:03.292222977    1   2  ...  19   0    NaN  240.0    NaN  0.0
# 2019-12-06 05:45:03.796188116    1   2  ...  19   0    NaN    NaN    NaN  0.0
# 2019-12-06 05:45:03.796189070    1   2  ...  19   0    NaN    NaN    NaN  0.0
#
#                                67  68   80        id
# timestamp
# 2019-12-06 02:05:04.415631056  -1  12   -1      1107
# 2019-12-06 02:05:04.415632010  -1  12   -1      1108
# 2019-12-06 02:05:04.532814026  -1  12   -1      3873
# 2019-12-06 02:05:04.532814980  -1  12   -1      3874
# 2019-12-06 02:05:04.913991928  -1  12   -1     14933
# ...                            ..  ..  ...       ...
# 2019-12-06 05:45:02.793700933  -1  12  204  21902947
# 2019-12-06 05:45:03.292222023  -1  12  204  21915746
# 2019-12-06 05:45:03.292222977  -1  12  204  21915747
# 2019-12-06 05:45:03.796188116  -1  12  204  21927579
# 2019-12-06 05:45:03.796189070  -1  12  204  21927580
#
# [84402 rows x 24 columns]

# %%
for col in df_bytes_converted.columns:
    plt.figure(figsize=(20,5))
    plt.plot(df_bytes_converted[col])
    plt.show()

# %%
df_train = df_bytes_converted.loc[:'2019-12-06 04:30:00'].copy().fillna(method='ffill')
df_train_id = df_train.pop('id')
df_train.head(3)
# Out:
#                                  5    7      8  19   21   22   30     32   33  \
# timestamp
# 2019-12-06 02:05:04.415631056  255  231  188.0   1  257  768  512  153.0  410
# 2019-12-06 02:05:04.415632010  255  231  188.0   1  257  768  512  153.0  410
# 2019-12-06 02:05:04.532814026  255  231  188.0   1  257  768  512  153.0  410
#
#                                35  ...   40  41  51     52     53     56   66  \
# timestamp                          ...
# 2019-12-06 02:05:04.415631056   2  ...  256  19   0  240.0  170.0  253.0  0.0
# 2019-12-06 02:05:04.415632010   2  ...  256  19   0  240.0  170.0  253.0  0.0
# 2019-12-06 02:05:04.532814026   2  ...  256  19   0  235.0  163.0  253.0  0.0
#
#                                67  68  80
# timestamp
# 2019-12-06 02:05:04.415631056  -1  12  -1
# 2019-12-06 02:05:04.415632010  -1  12  -1
# 2019-12-06 02:05:04.532814026  -1  12  -1
#
# [3 rows x 23 columns]

# %%
anomaly_idxs = [['2019-12-06 04:30:55', '2019-12-06 04:33:55'],
                ['2019-12-06 04:43:55', '2019-12-06 04:46:55'],
                ['2019-12-06 04:56:55', '2019-12-06 04:59:55'], 
                ['2019-12-06 05:09:55', '2019-12-06 05:12:55'], 
                ['2019-12-06 05:22:55', '2019-12-06 05:25:55']]

# %%
df_test = df_bytes_converted.loc['2019-12-06 04:30:00':].copy().fillna(method='ffill').fillna(method='bfill')
df_test_id = df_test.pop('id')

df_test['anomaly'] = 0

for idx in anomaly_idxs:
    df_test['anomaly'].loc[idx[0]:idx[1]] = 1

df_test.head(3)
# Out:
# /opt/python37/lib/python3.7/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
#                                  5    7      8  19   21   22   30       32  \
# timestamp
# 2019-12-06 04:30:00.014081001  255  234  188.0   1  257  512  512  43648.0
# 2019-12-06 04:30:00.014082909  255  234  188.0   1  257  512  512  43648.0
# 2019-12-06 04:30:00.518059968  255  234  188.0   1  257  512  512  43648.0
#
#                                 33  35  ...  41  51     52     53       56  \
# timestamp                               ...
# 2019-12-06 04:30:00.014081001  427   2  ...  19   0  190.0  161.0  60188.0
# 2019-12-06 04:30:00.014082909  427   2  ...  19   0  190.0  161.0  60188.0
# 2019-12-06 04:30:00.518059968  427   2  ...  19   0  155.0  161.0  60188.0
#
#                                 66  67  68     80  anomaly
# timestamp
# 2019-12-06 04:30:00.014081001  0.0  -1  12  51916        0
# 2019-12-06 04:30:00.014082909  0.0  -1  12  51916        0
# 2019-12-06 04:30:00.518059968  0.0  -1  12  52172        0
#
# [3 rows x 24 columns]

# %%
summary = {}

# %% [markdown]
# ## Подготовка train/test

# %%
x_train, x_test, y_test = get_traintest(df_train.copy(), df_test.copy())
# Out:
# Scaling... (Standard)
# Количество аномалий: 20.1%
#
# Counter({0: 23968, 1: 6034})
# Размеры выборок:
#             x_train: (54406, 23)
#             x_test: (30002, 23)
#             y_test: (30002,)

# %% [markdown]
# ## OC SVM

# %%
description='SWATDec19_svm_default'

model = OCSVM()
predictor = Predictor(model, [x_train, x_test, y_test], descr=description, resave_model=True)
# Out:
# 2022-09-09 07:51:28.367539: refit model...

# %%
y_pred = predictor.get_anomalies()
summary[description] = predictor.get_score()
# Out:
# SWATDec19_svm_default
# f1_score: 0.63
# accuracy_score: 0.76
# precision_score: 0.46
# recall_score: 1.00

# %%
plot_result(df_test, y_test, y_pred, descr=description)

# %%
description='SWATDec19_svm_minmax'

x_train, x_test, y_test = get_traintest(df_train.copy(), 
                                        df_test.copy(),
                                        scaler='MinMax')

predictor = Predictor(model, [x_train, x_test, y_test], descr=description)

y_pred = predictor.get_anomalies()
summary[description] = predictor.get_score()
plot_result(df_test, y_test, y_pred, descr=description)
# Out:
# Scaling... (MinMax)
# Количество аномалий: 20.1%
#
# Counter({0: 23968, 1: 6034})
# Размеры выборок:
#             x_train: (54406, 23)
#             x_test: (30002, 23)
#             y_test: (30002,)
# 2022-09-09 07:51:31.727591: find saved model: ./saved_models/SWATDec19_svm_minmax, loading...
# SWATDec19_svm_minmax
# f1_score: 0.47
# accuracy_score: 0.54
# precision_score: 0.30
# recall_score: 1.00

# %% [markdown]
# ## LOF

# %%
anomaly_idx = [i for i in range(len(y_test)) if y_test[i] == 1]

# %%
x_train, x_test, y_test = get_traintest(df_train.copy(), 
                                        df_test.copy())
# Out:
# Scaling... (Standard)
# Количество аномалий: 20.1%
#
# Counter({0: 23968, 1: 6034})
# Размеры выборок:
#             x_train: (54406, 23)
#             x_test: (30002, 23)
#             y_test: (30002,)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
principalComponents = pca.fit(x_train)

x_train_2d = pd.DataFrame(data = principalComponents.transform(x_train))
x_test_2d = pd.DataFrame(data = principalComponents.transform(x_test))
x_test_2d.plot(figsize=(20,5))

fig, (ax, ax_test) = plt.subplots(1, 2)
x_train_2d.plot.scatter(x=[1], y=[0], title='train', ax=ax)
x_test_2d.plot.scatter(x=[1], y=[0], title='test', ax=ax_test)
x_test_2d.iloc[anomaly_idx].plot.scatter(x=[1], y=[0], title='test', c='r', ax=ax_test)
plt.show()
# Out:
# /opt/python37/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:331: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():

# %%
N_COMPONENTS = 5

pca = PCA(n_components=N_COMPONENTS)
principalComponents = pca.fit(x_train)

x_train_pca = pd.DataFrame(data = principalComponents.transform(x_train))
x_test_pca = pd.DataFrame(data = principalComponents.transform(x_test))
x_test_pca.plot(figsize=(20,5))
plt.show()

# %%
model = LOF()

# %%
description = f'SWATDec19_lof_n_{N_COMPONENTS}'
predictor = Predictor(model, [x_train_pca, x_test_pca, y_test], descr=description, resave_model=True)

y_pred = predictor.get_anomalies()
summary[description] = predictor.get_score()
plot_result(df_test, y_test, y_pred, descr=description)
# Out:
# 2022-09-09 07:51:35.230504: refit model...
# Train prediction score statistics
#             min: -4908082782.377208
#             mean: -1894967.4101900721
#             max: -0.8378864240372235
# SWATDec19_lof_n_5
# f1_score: 0.27
# accuracy_score: 0.80
# precision_score: 0.50
# recall_score: 0.18

# %%
threshold=-1

y_pred = predictor.get_anomalies(threshold=threshold)
summary[f'{description}_thresh_{threshold}'] = predictor.get_score()
plot_result(df_test, y_test, y_pred, descr=f'{description}_thresh_{threshold}')
# Out:
# SWATDec19_lof_n_5
# f1_score: 0.34
# accuracy_score: 0.20
# precision_score: 0.20
# recall_score: 1.00

# %% [markdown]
# ## iForest

# %%
description = f'SWATDec19_iF_default'

x_train, x_test, y_test = get_traintest(df_train.copy(), df_test.copy())

model = iForest()

predictor = Predictor(model, [x_train, x_test, y_test], descr=description, resave_model=False)
y_pred = predictor.get_anomalies()
summary[description] = predictor.get_score()
plot_result(df_test, y_test, y_pred, descr=description)
# Out:
# Scaling... (Standard)
# Количество аномалий: 20.1%
#
# Counter({0: 23968, 1: 6034})
# Размеры выборок:
#             x_train: (54406, 23)
#             x_test: (30002, 23)
#             y_test: (30002,)
# 2022-09-09 07:51:41.010802: find saved model: ./saved_models/SWATDec19_iF_default, loading...
# SWATDec19_iF_default
# f1_score: 0.00
# accuracy_score: 0.79
# precision_score: 0.00
# recall_score: 0.00

# %%
description = f'SWATDec19_iF_n_200_c_0005'

x_train, x_test, y_test = get_traintest(df_train.copy(), 
                                        df_test.copy())

model = iForest(n_estimators=200, contamination=0.005)

predictor = Predictor(model, [x_train, x_test, y_test], descr=description, resave_model=True)
y_pred = predictor.get_anomalies()
summary[description] = predictor.get_score()
plot_result(df_test, y_test, y_pred, descr=description)
# Out:
# Scaling... (Standard)
# Количество аномалий: 20.1%
#
# Counter({0: 23968, 1: 6034})
# Размеры выборок:
#             x_train: (54406, 23)
#             x_test: (30002, 23)
#             y_test: (30002,)
# 2022-09-09 07:51:42.964375: refit model...
# SWATDec19_iF_n_200_c_0005
# f1_score: 0.00
# accuracy_score: 0.78
# precision_score: 0.00
# recall_score: 0.00

# %% [markdown]
# ## Autoencoder

# %%
window_size = 30
resample_rate = '1T'

description = f'SWATDec19_ae_lstm_window_{window_size}_resample_{resample_rate}'

x_train, x_test, y_test = get_traintest(df_train.copy(), 
                                        df_test.copy(), 
                                        window_size=window_size, 
                                        resample_rate=resample_rate)

model = AE_LSTM()

predictor = Predictor(model, 
                      [x_train, x_test, y_test], 
                      descr=description, 
                      window_size=window_size,
                      resave_model=False)

y_pred = predictor.get_anomalies()
summary[description] = predictor.get_score()
plot_result(df_test, y_test[:,0], y_pred, descr=description)
# Out:
# Scaling... (Standard)
# Количество аномалий: 20.1%
#
# Counter({0: 23968, 1: 6034})
# Resampling... (1T)
# (146, 23), (76, 23), (76,),
# Create sequences with window size 30...
# Размеры выборок:
#             x_train: (54377, 30, 23)
#             x_test: (29973, 30, 23)
#             y_test: (29973, 30)
# 2022-09-09 07:51:48.202838: find saved model: ./saved_models/SWATDec19_ae_lstm_window_30_resample_1T, loading...
# 2022-09-09 07:51:48.114243: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2022-09-09 07:51:48.145895: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-09 07:51:48.146399: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:02:00.0 name: GeForce RTX 2070 SUPER computeCapability: 7.5
# coreClock: 1.8GHz coreCount: 40 deviceMemorySize: 7.79GiB deviceMemoryBandwidth: 417.29GiB/s
# 2022-09-09 07:51:48.146458: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-09 07:51:48.146950: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 1 with properties:
# pciBusID: 0000:0a:00.0 name: GeForce RTX 2070 SUPER computeCapability: 7.5
# coreClock: 1.8GHz coreCount: 40 deviceMemorySize: 7.79GiB deviceMemoryBandwidth: 417.29GiB/s
# 2022-09-09 07:51:48.147022: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory
# 2022-09-09 07:51:48.147305: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcublas.so.10'; dlerror: libcublas.so.10: cannot open shared object file: No such file or directory
# 2022-09-09 07:51:48.147374: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory
# 2022-09-09 07:51:48.147663: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcurand.so.10'; dlerror: libcurand.so.10: cannot open shared object file: No such file or directory
# 2022-09-09 07:51:48.147728: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcusolver.so.10'; dlerror: libcusolver.so.10: cannot open shared object file: No such file or directory
# 2022-09-09 07:51:48.147781: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcusparse.so.10'; dlerror: libcusparse.so.10: cannot open shared object file: No such file or directory
# 2022-09-09 07:51:48.147833: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudnn.so.7'; dlerror: libcudnn.so.7: cannot open shared object file: No such file or directory
# 2022-09-09 07:51:48.147840: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1753] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2022-09-09 07:51:48.148108: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-09 07:51:48.179648: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 3600000000 Hz
# 2022-09-09 07:51:48.181987: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5575c9177f20 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2022-09-09 07:51:48.182042: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2022-09-09 07:51:48.186257: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1257] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-09-09 07:51:48.186296: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1263]
# Train prediction score statistics
#             min: 0.6062323983253745
#             mean: 2.3749894523683435
#             max: 25.31295553481528
# (29973,)
# SWATDec19_ae_lstm_window_30_resample_1T
# f1_score: 0.86
# accuracy_score: 0.94
# precision_score: 0.76
# recall_score: 1.00

# %%
threshold=800

y_pred = predictor.get_anomalies(threshold=threshold)
summary[f'{description}_thresh_{threshold}'] = predictor.get_score()
plot_result(df_test, y_test[:,0], y_pred, descr=f'{description}_thresh_{threshold}')
# Out:
# (29973,)
# SWATDec19_ae_lstm_window_30_resample_1T
# f1_score: 0.38
# accuracy_score: 0.85
# precision_score: 1.00
# recall_score: 0.23

# %%
threshold=400

y_pred = predictor.get_anomalies(threshold=threshold)
summary[f'{description}_thresh_{threshold}'] = predictor.get_score()
plot_result(df_test, y_test[:,0], y_pred, descr=f'{description}_thresh_{threshold}')
# Out:
# (29973,)
# SWATDec19_ae_lstm_window_30_resample_1T
# f1_score: 0.60
# accuracy_score: 0.88
# precision_score: 1.00
# recall_score: 0.43

# %% [markdown]
# ## SOM

# %%
x_train, x_test, y_test = get_traintest(df_train.copy(), 
                                        df_test.copy())
# Out:
# Scaling... (Standard)
# Количество аномалий: 20.1%
#
# Counter({0: 23968, 1: 6034})
# Размеры выборок:
#             x_train: (54406, 23)
#             x_test: (30002, 23)
#             y_test: (30002,)

# %%
description = f'SWATDec19_som_default'

model = SOM(x_train)

predictor = Predictor(model, 
                      [x_train, x_test, y_test], 
                      descr=description,
                      resave_model=False)

y_pred = predictor.get_anomalies()
summary[description] = predictor.get_score()
plot_result(df_test, y_test, y_pred, descr=description)
# Out:
# 2022-09-09 08:20:14.353422: can't find saved model, fit model...
# 50000
# IntProgress(value=0, description='Computing', max=30002, style=ProgressStyle(bar_color='#61dc8a'))
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# IntProgress(value=0, description='Computing', max=54406, style=ProgressStyle(bar_color='#61dc8a'))
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Train prediction score statistics
#             min: 0.03429652832829935
#             mean: 33.13457928040264
#             max: 143.6231971008983
# (30002,)
# SWATDec19_som_default
# f1_score: 0.16
# accuracy_score: 0.81
# precision_score: 0.68
# recall_score: 0.09

# %%
threshold=100

y_pred = predictor.get_anomalies(threshold=threshold)
summary[f'{description}_thresh_{threshold}'] = predictor.get_score()
plot_result(df_test, y_test, y_pred, descr=f'{description}_thresh_{threshold}')
# Out:
# IntProgress(value=0, description='Computing', max=30002, style=ProgressStyle(bar_color='#61dc8a'))
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# # Сводная таблица

# %%
def highlight_max(s, props=''):
    return np.where(s == np.nanmax(s.values), props, '')

df_summary = pd.DataFrame(summary).T
df_summary.style.background_gradient(cmap='Blues')
# Out:
# <style  type="text/css" >
# #T_e4a194be_3039_11ed_a759_ef642a95eb47row0_col0{
#             background-color:  #2676b8;
#             color:  #000000;
#         }#T_e4a194be_3039_11ed_a759_ef642a95eb47row0_col1{
#             background-color:  #1e6db2;
#             color:  #f1f1f1;
#         }#T_e4a194be_3039_11ed_a759_ef642a95eb47row0_col2,#T_e4a194be_3039_11ed_a759_ef642a95eb47row1_col1{
#             background-color:  #7cb7da;
#             color:  #000000;
#         }#T_e4a194be_3039_11ed_a759_ef642a95eb47row0_col3,#T_e4a194be_3039_11ed_a759_ef642a95eb47row1_col3,#T_e4a194be_3039_11ed_a759_ef642a95eb47row3_col3,#T_e4a194be_3039_11ed_a759_ef642a95eb47row6_col0,#T_e4a194be_3039_11ed_a759_ef642a95eb47row6_col1,#T_e4a194be_3039_11ed_a759_ef642a95eb47row6_col3,#T_e4a194be_3039_11ed_a759_ef642a95eb47row7_col2,#T_e4a194be_3039_11ed_a759_ef642a95eb47row8_col2{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_e4a194be_3039_11ed_a759_ef642a95eb47row1_col0{
#             background-color:  #5da5d1;
#             color:  #000000;
#         }#T_e4a194be_3039_11ed_a759_ef642a95eb47row1_col2{
#             background-color:  #b5d4e9;
#             color:  #000000;
#         }#T_e4a194be_3039_11ed_a759_ef642a95eb47row2_col0{
#             background-color:  #b3d3e8;
#             color:  #000000;
#         }#T_e4a194be_3039_11ed_a759_ef642a95eb47row2_col1{
#             background-color:  #1460a8;
#             color:  #f1f1f1;
#         }#T_e4a194be_3039_11ed_a759_ef642a95eb47row2_col2{
#             background-color:  #6aaed6;
#             color:  #000000;
#         }#T_e4a194be_3039_11ed_a759_ef642a95eb47row2_col3{
#             background-color:  #d3e4f3;
#             color:  #000000;
#         }#T_e4a194be_3039_11ed_a759_ef642a95eb47row3_col0{
#             background-color:  #99c7e0;
#             color:  #000000;
#         }#T_e4a194be_3039_11ed_a759_ef642a95eb47row3_col1,#T_e4a194be_3039_11ed_a759_ef642a95eb47row4_col0,#T_e4a194be_3039_11ed_a759_ef642a95eb47row4_col2,#T_e4a194be_3039_11ed_a759_ef642a95eb47row4_col3,#T_e4a194be_3039_11ed_a759_ef642a95eb47row5_col0,#T_e4a194be_3039_11ed_a759_ef642a95eb47row5_col2,#T_e4a194be_3039_11ed_a759_ef642a95eb47row5_col3{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_e4a194be_3039_11ed_a759_ef642a95eb47row3_col2{
#             background-color:  #d0e1f2;
#             color:  #000000;
#         }#T_e4a194be_3039_11ed_a759_ef642a95eb47row4_col1{
#             background-color:  #1663aa;
#             color:  #f1f1f1;
#         }#T_e4a194be_3039_11ed_a759_ef642a95eb47row5_col1{
#             background-color:  #1a68ae;
#             color:  #f1f1f1;
#         }#T_e4a194be_3039_11ed_a759_ef642a95eb47row6_col2{
#             background-color:  #1f6eb3;
#             color:  #f1f1f1;
#         }#T_e4a194be_3039_11ed_a759_ef642a95eb47row7_col0{
#             background-color:  #84bcdb;
#             color:  #000000;
#         }#T_e4a194be_3039_11ed_a759_ef642a95eb47row7_col1{
#             background-color:  #08509b;
#             color:  #f1f1f1;
#         }#T_e4a194be_3039_11ed_a759_ef642a95eb47row7_col3{
#             background-color:  #caddf0;
#             color:  #000000;
#         }#T_e4a194be_3039_11ed_a759_ef642a95eb47row8_col0{
#             background-color:  #2f7fbc;
#             color:  #000000;
#         }#T_e4a194be_3039_11ed_a759_ef642a95eb47row8_col1{
#             background-color:  #084285;
#             color:  #f1f1f1;
#         }#T_e4a194be_3039_11ed_a759_ef642a95eb47row8_col3{
#             background-color:  #89bedc;
#             color:  #000000;
#         }#T_e4a194be_3039_11ed_a759_ef642a95eb47row9_col0{
#             background-color:  #d3e3f3;
#             color:  #000000;
#         }#T_e4a194be_3039_11ed_a759_ef642a95eb47row9_col1{
#             background-color:  #125da6;
#             color:  #f1f1f1;
#         }#T_e4a194be_3039_11ed_a759_ef642a95eb47row9_col2{
#             background-color:  #3383be;
#             color:  #000000;
#         }#T_e4a194be_3039_11ed_a759_ef642a95eb47row9_col3{
#             background-color:  #e5eff9;
#             color:  #000000;
#         }#T_e4a194be_3039_11ed_a759_ef642a95eb47row10_col0{
#             background-color:  #2c7cba;
#             color:  #000000;
#         }#T_e4a194be_3039_11ed_a759_ef642a95eb47row10_col1{
#             background-color:  #084990;
#             color:  #f1f1f1;
#         }#T_e4a194be_3039_11ed_a759_ef642a95eb47row10_col2{
#             background-color:  #2777b8;
#             color:  #000000;
#         }#T_e4a194be_3039_11ed_a759_ef642a95eb47row10_col3{
#             background-color:  #63a8d3;
#             color:  #000000;
#         }</style><table id="T_e4a194be_3039_11ed_a759_ef642a95eb47" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >f1_score</th>        <th class="col_heading level0 col1" >accuracy_score</th>        <th class="col_heading level0 col2" >precision_score</th>        <th class="col_heading level0 col3" >recall_score</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e4a194be_3039_11ed_a759_ef642a95eb47level0_row0" class="row_heading level0 row0" >SWATDec19_svm_default</th>
#                         <td id="T_e4a194be_3039_11ed_a759_ef642a95eb47row0_col0" class="data row0 col0" >0.627936</td>
#                         <td id="T_e4a194be_3039_11ed_a759_ef642a95eb47row0_col1" class="data row0 col1" >0.762416</td>
#                         <td id="T_e4a194be_3039_11ed_a759_ef642a95eb47row0_col2" class="data row0 col2" >0.458321</td>
#                         <td id="T_e4a194be_3039_11ed_a759_ef642a95eb47row0_col3" class="data row0 col3" >0.996851</td>
#             </tr>
#             <tr>
#                         <th id="T_e4a194be_3039_11ed_a759_ef642a95eb47level0_row1" class="row_heading level0 row1" >SWATDec19_svm_minmax</th>
#                         <td id="T_e4a194be_3039_11ed_a759_ef642a95eb47row1_col0" class="data row1 col0" >0.465302</td>
#                         <td id="T_e4a194be_3039_11ed_a759_ef642a95eb47row1_col1" class="data row1 col1" >0.539531</td>
#                         <td id="T_e4a194be_3039_11ed_a759_ef642a95eb47row1_col2" class="data row1 col2" >0.303540</td>
#                         <td id="T_e4a194be_3039_11ed_a759_ef642a95eb47row1_col3" class="data row1 col3" >0.996188</td>
#             </tr>
#             <tr>
#                         <th id="T_e4a194be_3039_11ed_a759_ef642a95eb47level0_row2" class="row_heading level0 row2" >SWATDec19_lof_n_5</th>
#                         <td id="T_e4a194be_3039_11ed_a759_ef642a95eb47row2_col0" class="data row2 col0" >0.268207</td>
#                         <td id="T_e4a194be_3039_11ed_a759_ef642a95eb47row2_col1" class="data row2 col1" >0.799380</td>
#                         <td id="T_e4a194be_3039_11ed_a759_ef642a95eb47row2_col2" class="data row2 col2" >0.503423</td>
#                         <td id="T_e4a194be_3039_11ed_a759_ef642a95eb47row2_col3" class="data row2 col3" >0.182797</td>
#             </tr>
#             <tr>
#                         <th id="T_e4a194be_3039_11ed_a759_ef642a95eb47level0_row3" class="row_heading level0 row3" >SWATDec19_lof_n_5_thresh_-1</th>
#                         <td id="T_e4a194be_3039_11ed_a759_ef642a95eb47row3_col0" class="data row3 col0" >0.335586</td>
#                         <td id="T_e4a194be_3039_11ed_a759_ef642a95eb47row3_col1" class="data row3 col1" >0.203620</td>
#                         <td id="T_e4a194be_3039_11ed_a759_ef642a95eb47row3_col2" class="data row3 col2" >0.201624</td>
#                         <td id="T_e4a194be_3039_11ed_a759_ef642a95eb47row3_col3" class="data row3 col3" >1.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_e4a194be_3039_11ed_a759_ef642a95eb47level0_row4" class="row_heading level0 row4" >SWATDec19_iF_default</th>
#                         <td id="T_e4a194be_3039_11ed_a759_ef642a95eb47row4_col0" class="data row4 col0" >0.000000</td>
#                         <td id="T_e4a194be_3039_11ed_a759_ef642a95eb47row4_col1" class="data row4 col1" >0.791714</td>
#                         <td id="T_e4a1
